# %%
import IPython.frontend.html.notebook.flot as flt

# %%
import numpy as npx = np.linspace(0,10,100)y = np.sin(x)plt = flt.Plot()plt.plot_figure([x,x],[y,y**2],label=["bob",'alice'])
# Out:
#         <div id="placeholder0"" style="width:        600px;height:300px;"></div>

# %%
plt.pixelsx =  400plt.pixelsy =  300plt.legendloc ='se'plt.plot_figure(x**2,y,label='alice')
# Out:
#         <div id="placeholder1"" style="width:        400px;height:300px;"></div>
