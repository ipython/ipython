# %% [markdown]
# # Interact Demos

# %% [markdown]
# This Notebook shows basic demonstrations of IPython `interact` module. This provides a high-level interface for creating user interface controls to use in exploring code and data interactively.

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.html.widgets.interact import interact, interactive
from IPython.html import widgets
from IPython.display import clear_output, display, HTML

# %% [markdown]
# ## Basic interact

# %% [markdown]
# Here is a simple function that displays its arguments as an HTML table:

# %%
def show_args(**kwargs):
    s = '<h3>Arguments:</h3><table>\n'
    for k,v in kwargs.items():
        s += '<tr><td>{0}</td><td>{1}</td></tr>\n'.format(k,v)
    s += '</table>'
    display(HTML(s))

# %%
show_args(a=10, b='Hi There', c=True)
# Out:
# <h3>Arguments:</h3><table>
# <tr><td>a</td><td>10</td></tr>
# <tr><td>c</td><td>True</td></tr>
# <tr><td>b</td><td>Hi There</td></tr>
# </table>

# %% [markdown]
# Let's use this function to explore how `interact` works.

# %%
interact(show_args,
         Temp=(0,10),
         Current=(0.,10.,0.01),
         z=True,
         Text=u'Type here!',
         Algorithm=['This','That','Other'],
         a=widgets.FloatSliderWidget(min=-10.0, max=10.0, step=0.1, value=5.0)
         )
# Out:
# <h3>Arguments:</h3><table>
# <tr><td>a</td><td>0.3</td></tr>
# <tr><td>Algorithm</td><td>This</td></tr>
# <tr><td>Temp</td><td>5</td></tr>
# <tr><td>Text</td><td>Type here!</td></tr>
# <tr><td>Current</td><td>5.0</td></tr>
# <tr><td>z</td><td>True</td></tr>
# </table>

# %% [markdown]
# The keyword arguments to `interact` can be any `Widget` instance that has a `value` and `description` attribute, or one of the shorthand notations shown above.

# %% [markdown]
# ## Factoring polynomials

# %% [markdown]
# Here is an example that uses [SymPy](http://sympy.org/en/index.html) to factor polynomials.

# %%
from sympy import Symbol, Eq, factor, init_printing
init_printing()

# %%
x = Symbol('x')

# %%
def factorit(n):
    display(Eq(x**n-1, factor(x**n-1)))

# %% [markdown]
# Notice how the output of the `factorit` function is properly formatted LaTeX.

# %%
interact(factorit, n=(2,40))
# Out:
#  21               ⎛ 2        ⎞ ⎛ 6    5    4    3    2        ⎞ ⎛ 12    11
# x   - 1 = (x - 1)⋅⎝x  + x + 1⎠⋅⎝x  + x  + x  + x  + x  + x + 1⎠⋅⎝x   - x   + x
#
# 9    8    6    4    3        ⎞
#   - x  + x  - x  + x  - x + 1⎠

# %% [markdown]
# ## A simple image browser

# %% [markdown]
# This example shows how to browse through a set of images with a slider.

# %%
from sklearn import datasets

# %% [markdown]
# We will use the digits dataset from [scikit-learn](http://scikit-learn.org/stable/).

# %%
digits = datasets.load_digits()

# %%
def browse_images(digits):
    n = len(digits.images)
    def view_image(i):
        imshow(digits.images[i], cmap=cm.gray_r, interpolation='nearest')
        title('Training: %s' % digits.target[i])
        show()
    interact(view_image, i=(0,n-1))

# %%
browse_images(digits)

# %% [markdown]
# ## Explore random graphs

# %% [markdown]
# In this example, we build a simple UI for exploring random graphs with [NetworkX](http://networkx.github.io/).

# %%
import networkx as nx

# %%
def plot_random_graph(n, p, generator):
    g = generator(n,p)
    nx.draw(g)
    show()

# %%
interact(plot_random_graph, n=(2,30), p=(0.0, 1.0, 0.001),
        generator={'gnp': nx.gnp_random_graph,
                   'erdos_renyi': nx.erdos_renyi_graph,
                   'binomial': nx.binomial_graph})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-c2e115f84112> in <module>()
#       2         generator={'gnp': nx.gnp_random_graph,
#       3                    'erdos_renyi': nx.erdos_renyi_graph,
# ----> 4                    'binomial': nx.binomial_graph})
#
# /Users/bgranger/Documents/Computing/IPython/code/ipython/IPython/html/widgets/interact.py in interact(f, **kwargs)
#     135
#     136 def interact(f, **kwargs):
# --> 137     w = interactive(f, **kwargs)
#     138     display(w)
#
# /Users/bgranger/Documents/Computing/IPython/code/ipython/IPython/html/widgets/interact.py in interactive(f, **kwargs)
#     107             widget = value
#     108         else:
# --> 109             widget = _widget_abbrev(value)
#     110             if widget is None:
#     111                 raise ValueError("Object cannot be transformed to a Widget")
#
# /Users/bgranger/Documents/Computing/IPython/code/ipython/IPython/html/widgets/interact.py in _widget_abbrev(o)
#      61         labels = [unicode_type(k) for k in o]
#      62         values = o.values()
# ---> 63         w = DropdownWidget(value=values[0], values=values, labels=labels)
#      64         return w
#      65     # Special case float and int == 0.0
#
# /Users/bgranger/Documents/Computing/IPython/code/ipython/IPython/html/widgets/widget_selection.pyc in __init__(self, *pargs, **kwargs)
#      37         self.value_lock = Lock()
#      38         self.on_trait_change(self._string_value_set, ['_value'])
# ---> 39         DOMWidget.__init__(self, *pargs, **kwargs)
#      40
#      41     def _labels_changed(self, name=None, old=None, new=None):
#
# /Users/bgranger/Documents/Computing/IPython/code/ipython/IPython/html/widgets/widget.pyc in __init__(self, **kwargs)
#     102     def __init__(self, **kwargs):
#     103         """Public constructor"""
# --> 104         super(Widget, self).__init__(**kwargs)
#     105
#     106         self.on_trait_change(self._handle_property_changed, self.keys)
#
# /Users/bgranger/Documents/Computing/IPython/code/ipython/IPython/config/configurable.pyc in __init__(self, **kwargs)
#     100         # This should go second so individual keyword arguments override
#     101         # the values in config.
# --> 102         super(Configurable, self).__init__(**kwargs)
#     103
#     104     #-------------------------------------------------------------------------
#
# /Users/bgranger/Documents/Computing/IPython/code/ipython/IPython/utils/traitlets.pyc in __init__(self, *args, **kw)
#     430         # notifications.
#     431         for key, value in iteritems(kw):
# --> 432             setattr(self, key, value)
#     433
#     434     def _notify_trait(self, name, old_value, new_value):
#
# /Users/bgranger/Documents/Computing/IPython/code/ipython/IPython/utils/traitlets.pyc in __set__(self, obj, value)
#     318         obj._trait_values[self.name] = new_value
#     319         if old_value != new_value:
# --> 320             obj._notify_trait(self.name, old_value, new_value)
#     321
#     322     def _validate(self, obj, value):
#
# /Users/bgranger/Documents/Computing/IPython/code/ipython/IPython/utils/traitlets.pyc in _notify_trait(self, name, old_value, new_value)
#     467                     c(name, new_value)
#     468                 elif nargs + offset == 3:
# --> 469                     c(name, old_value, new_value)
#     470                 else:
#     471                     raise TraitError('a trait changed callback '
#
# /Users/bgranger/Documents/Computing/IPython/code/ipython/IPython/html/widgets/widget_selection.pyc in _labels_changed(self, name, old, new)
#      45         value for the value_names Dict."""
#      46         if len(new) != len(self.values):
# ---> 47             raise TypeError('Labels list must be the same size as the values list.')
#      48
#      49     def _values_changed(self, name=None, old=None, new=None):
#
# TypeError: Labels list must be the same size as the values list.

# %% [markdown]
# ## Image manipulation

# %% [markdown]
# This example builds a simple UI for performing basic image manipulation with [scikit-image](http://scikit-image.org/).

# %%
import skimage
from skimage import data, filter, io

# %%
i = data.coffee()

# %%
io.Image(i)
# Out:
# /Users/bgranger/Documents/Computing/IPython/code/ipython/IPython/core/formatters.py:199: FormatterWarning: Exception in image/jpeg formatter: fileno
#   FormatterWarning,
# Image([[[ 21,  13,   8],
#         [ 21,  13,   9],
#         [ 20,  11,   8],
#         ...,
#         [228, 182, 138],
#         [231, 185, 142],
#         [228, 184, 140]],
#
#        [[ 21,  13,   7],
#         [ 21,  13,   9],
#         [ 20,  14,   7],
#         ...,
#         [228, 182, 136],
#         [231, 185, 139],
#         [229, 183, 137]],
#
#        [[ 21,  14,   7],
#         [ 23,  13,  10],
#         [ 20,  14,   9],
#         ...,
#         [228, 182, 136],
#         [228, 184, 137],
#         [229, 185, 138]],
#
#        ...,
#        [[189, 124,  77],
#         [214, 155, 109],
#         [197, 141, 100],
#         ...,
#         [165,  86,  37],
#         [161,  82,  41],
#         [143,  67,  29]],
#
#        [[207, 148, 102],
#         [201, 142,  99],
#         [196, 140,  97],
#         ...,
#         [154,  74,  37],
#         [147,  66,  33],
#         [145,  65,  31]],
#
#        [[197, 141, 100],
#         [195, 137,  99],
#         [193, 138,  98],
#         ...,
#         [158,  73,  38],
#         [144,  64,  30],
#         [143,  60,  29]]], dtype=uint8)

# %%
def edit_image(image):
    def apply_filter(sigma, r, g, b):
        new_image = filter.gaussian_filter(image, sigma=sigma)
        new_image[:,:,0] = r*new_image[:,:,0]
        new_image[:,:,1] = g*new_image[:,:,1]
        new_image[:,:,2] = b*new_image[:,:,2]
        new_image = io.Image(new_image)
        display(new_image)
        return new_image
    lims = (0.0,1.0,0.01)
    return interactive(apply_filter, sigma=(0.1,10.0,0.01), r=lims, g=lims, b=lims)

# %%
w = edit_image(i)

# %%
display(w)
# Out:
# Image([[[ 0.04117149,  0.02579781,  0.01496551],
#         [ 0.04133345,  0.02597038,  0.01512557],
#         [ 0.04152955,  0.02617473,  0.01528648],
#         ...,
#         [ 0.43994913,  0.3501207 ,  0.25920288],
#         [ 0.44111969,  0.3515919 ,  0.26041334],
#         [ 0.4421297 ,  0.35288512,  0.26145989]],
#
#        [[ 0.0410792 ,  0.02575286,  0.01480705],
#         [ 0.04125425,  0.02593205,  0.01498111],
#         [ 0.04146479,  0.02614398,  0.01515888],
#         ...,
#         [ 0.43922855,  0.34937555,  0.25851024],
#         [ 0.44032212,  0.35067654,  0.25951671],
#         [ 0.44127753,  0.35183381,  0.26039917]],
#
#        [[ 0.04096664,  0.02569224,  0.01465927],
#         [ 0.04115624,  0.02587791,  0.01484428],
#         [ 0.04138281,  0.02609743,  0.01503602],
#         ...,
#         [ 0.43836516,  0.34845857,  0.25768523],
#         [ 0.43936013,  0.3495534 ,  0.25844767],
#         [ 0.44024237,  0.35054287,  0.25912975]],
#
#        ...,
#        [[ 0.38192341,  0.27012777,  0.18343927],
#         [ 0.38328831,  0.27187895,  0.18498296],
#         [ 0.38477842,  0.27381874,  0.18666331],
#         ...,
#         [ 0.29078038,  0.13270043,  0.0606862 ],
#         [ 0.29133476,  0.13296099,  0.06092731],
#         [ 0.29174249,  0.13309905,  0.0611007 ]],
#
#        [[ 0.38269779,  0.27113608,  0.18475336],
#         [ 0.38409529,  0.27291731,  0.18632753],
#         [ 0.38562169,  0.27488927,  0.18804115],
#         ...,
#         [ 0.29055308,  0.13239845,  0.06076095],
#         [ 0.29102522,  0.13248186,  0.06089767],
#         [ 0.29130359,  0.13241956,  0.06095917]],
#
#        [[ 0.38366501,  0.27234023,  0.1862438 ],
#         [ 0.38506856,  0.2741188 ,  0.1878183 ],
#         [ 0.38660347,  0.27608825,  0.18953337],
#         ...,
#         [ 0.2902744 ,  0.13199198,  0.06077198],
#         [ 0.29064282,  0.13188657,  0.06080287],
#         [ 0.29077682,  0.13161713,  0.06075318]]])

# %%
w.kwargs
# Out:
# {b: 0.49, g: 0.5, r: 0.5, sigma: 5.05}

# %%
w.result
# Out:
# Image([[[ 0.04117149,  0.02579781,  0.01496551],
#         [ 0.04133345,  0.02597038,  0.01512557],
#         [ 0.04152955,  0.02617473,  0.01528648],
#         ...,
#         [ 0.43994913,  0.3501207 ,  0.25920288],
#         [ 0.44111969,  0.3515919 ,  0.26041334],
#         [ 0.4421297 ,  0.35288512,  0.26145989]],
#
#        [[ 0.0410792 ,  0.02575286,  0.01480705],
#         [ 0.04125425,  0.02593205,  0.01498111],
#         [ 0.04146479,  0.02614398,  0.01515888],
#         ...,
#         [ 0.43922855,  0.34937555,  0.25851024],
#         [ 0.44032212,  0.35067654,  0.25951671],
#         [ 0.44127753,  0.35183381,  0.26039917]],
#
#        [[ 0.04096664,  0.02569224,  0.01465927],
#         [ 0.04115624,  0.02587791,  0.01484428],
#         [ 0.04138281,  0.02609743,  0.01503602],
#         ...,
#         [ 0.43836516,  0.34845857,  0.25768523],
#         [ 0.43936013,  0.3495534 ,  0.25844767],
#         [ 0.44024237,  0.35054287,  0.25912975]],
#
#        ...,
#        [[ 0.38192341,  0.27012777,  0.18343927],
#         [ 0.38328831,  0.27187895,  0.18498296],
#         [ 0.38477842,  0.27381874,  0.18666331],
#         ...,
#         [ 0.29078038,  0.13270043,  0.0606862 ],
#         [ 0.29133476,  0.13296099,  0.06092731],
#         [ 0.29174249,  0.13309905,  0.0611007 ]],
#
#        [[ 0.38269779,  0.27113608,  0.18475336],
#         [ 0.38409529,  0.27291731,  0.18632753],
#         [ 0.38562169,  0.27488927,  0.18804115],
#         ...,
#         [ 0.29055308,  0.13239845,  0.06076095],
#         [ 0.29102522,  0.13248186,  0.06089767],
#         [ 0.29130359,  0.13241956,  0.06095917]],
#
#        [[ 0.38366501,  0.27234023,  0.1862438 ],
#         [ 0.38506856,  0.2741188 ,  0.1878183 ],
#         [ 0.38660347,  0.27608825,  0.18953337],
#         ...,
#         [ 0.2902744 ,  0.13199198,  0.06077198],
#         [ 0.29064282,  0.13188657,  0.06080287],
#         [ 0.29077682,  0.13161713,  0.06075318]]])

# %% [markdown]
# ## Playing with audio

# %% [markdown]
# This example uses the `Audio` object and Matplotlib to explore the phenomenon of beat frequencies.

# %%
from IPython.display import Audio
import numpy as np

# %%
def beat_freq(f1=220.0, f2=224.0):
    max_time = 3
    rate = 8000
    times = np.linspace(0,max_time,rate*max_time)
    signal = np.sin(2*np.pi*f1*times) + np.sin(2*np.pi*f2*times)
    print f1, f2, abs(f1-f2)
    display(Audio(data=signal, rate=rate))
    return signal

# %%
v = interactive(beat_freq, f1=(200.0,300.0), f2=(200.0,300.0))
display(v)
# Out:
# 265.1 250.0 15.1
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot(v.result[0:6000])
